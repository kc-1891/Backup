# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Pandas.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
df1 = pd.read_csv("supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.set_index('ID')
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = pd.read_json("supermarkets.json")

# %%
df2
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3 = pd.read_csv('supermarkets-commas.txt')
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df3 = pd.read_csv('supermarkets-semi-colons.txt', sep=';')
df3
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4 = pd.read_excel('supermarkets.xlsx')
df4
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df5 = pd.read_csv('http://pythonhow.com/supermarkets.csv')
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
m = df5.Employees.max()

# %%
s = df5.Employees.sum()

# %%
print('Maximum emp:',df5.Employees.max(),'& Total emp:',df5.Employees.sum())
# Out:
# Maximum emp: 25 & Total emp: 90

# %%
#Learning slicing and dicing the DF

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.loc["332 Hill St": "1056 Sanchez St",  "State": "Name" ]
# Out:
# Empty DataFrame
# Columns: [State, Country, Name]
# Index: []

# %%
df5.iloc[:, 2:5]
# Out:
#             City             State Country
# 0  San Francisco          CA 94114     USA
# 1  San Francisco          CA 94119     USA
# 2  San Francisco  California 94114     USA
# 3  San Francisco          CA 94114     USA
# 4  San Francisco        California     USA
# 5  San Francisco          CA 94114     USA

# %%
df5.set_index('City')
# Out:
#                ID          Address             State Country         Name  \
# City
# San Francisco   1     3666 21st St          CA 94114     USA      Madeira
# San Francisco   2   735 Dolores St          CA 94119     USA  Bready Shop
# San Francisco   3      332 Hill St  California 94114     USA  Super River
# San Francisco   4     3995 23rd St          CA 94114     USA   Ben's Shop
# San Francisco   5  1056 Sanchez St        California     USA      Sanchez
# San Francisco   6  551 Alvarado St          CA 94114     USA   Richvalley
#
#                Employees
# City
# San Francisco          8
# San Francisco         15
# San Francisco         25
# San Francisco         10
# San Francisco         12
# San Francisco         20

# %%
df5.set_column?
# Out:
# Object `df5.set_column` not found.

# %%
df5.set_col?
# Out:
# Object `df5.set_col` not found.

# %%
df5?

# %%
df5.loc[:, "Country"]
# Out:
# 0    USA
# 1    USA
# 2    USA
# 3    USA
# 4    USA
# 5    USA
# Name: Country, dtype: object

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.loc[:, "City": "Employees"]
# Out:
#             City             State Country         Name  Employees
# 0  San Francisco          CA 94114     USA      Madeira          8
# 1  San Francisco          CA 94119     USA  Bready Shop         15
# 2  San Francisco  California 94114     USA  Super River         25
# 3  San Francisco          CA 94114     USA   Ben's Shop         10
# 4  San Francisco        California     USA      Sanchez         12
# 5  San Francisco          CA 94114     USA   Richvalley         20

# %%
df5.iloc[:, 1:]
# Out:
#            Address           City             State Country         Name  \
# 0     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2      332 Hill St  San Francisco  California 94114     USA  Super River
# 3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.ix[3:,"State": ]
# Out:
# /Users/Kumaran/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.
#         State Country        Name  Employees
# 3    CA 94114     USA  Ben's Shop         10
# 4  California     USA     Sanchez         12
# 5    CA 94114     USA  Richvalley         20

# %%
#Dropping columns and row
#________________________________________________________

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.drop("City", 1)
# Out:
#    ID          Address             State Country         Name  Employees
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df5.drop("332 Hill St", 0)
# Out:
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# <ipython-input-95-01b30b2c6a43> in <module>()
# ----> 1 df5.drop("332 Hill St", 0)
#
# /Users/Kumaran/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2048                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2049             else:
# -> 2050                 new_axis = axis.drop(labels, errors=errors)
#    2051             dropped = self.reindex(**{axis_name: new_axis})
#    2052             try:
#
# /Users/Kumaran/anaconda/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3573             if errors != 'ignore':
#    3574                 raise ValueError('labels %s not contained in axis' %
# -> 3575                                  labels[mask])
#    3576             indexer = indexer[~mask]
# ...

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5.drop(df5.index[1:3],0)                         # Dropping rows based on index

# %%
df5

# %%
df5.drop(df5.columns[:3], 1)                        #Dropping first 3 columns

# %%
df5.index

# %%
df5.columns

# %%
# Adding columns and rows to the DF

# %%
df5

# %%
len(df5.index)
# Out:
# 6

# %%
df5.shape
# Out:
# (6, 7)

# %%
df5["Continent"] = df5.shape[0] * ["North America"]

# %%
df5["Continent"] = df5["Country"] + ',,' + "North America"

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df5["Continent"] = df5["Country"] + ',,' + df5["Continent"]

# %%
df5
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees      Continent
# 0          8  North America
# 1         15  North America
# 2         25  North America
# 3         10  North America
# 4         12  North America
# 5         20  North America

# %%
df5_T = df5.T

# %%
df5_T
# Out:
#                        0               1                 2              3  \
# ID                     1               2                 3              4
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  North America   North America     North America  North America
#
#                          4                5
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# State           California         CA 94114
# Country                USA              USA
# ...

# %%
df5_T["2 Freshers Grove"] = ["7","Reading", 'Berkshire', 'UK', 'Kumaran Shop', '45', 'UK']
# Out:
# -----------------------------------------------------------------------
# ValueError                            Traceback (most recent call last)
# <ipython-input-105-3a078b766648> in <module>()
# ----> 1 df5_T["2 Freshers Grove"] = ["7","Reading", 'Berkshire', 'UK', 'Kumaran Shop', '45', 'UK']
#
# /Users/Kumaran/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# /Users/Kumaran/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# /Users/Kumaran/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
# ...

# %%
df5_T
# Out:
#                        0               1                 2              3  \
# ID                     1               2                 3              4
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# State           CA 94114        CA 94119  California 94114       CA 94114
# Country              USA             USA               USA            USA
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# Employees              8              15                25             10
# Continent  North America   North America     North America  North America
#
#                          4                5
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# State           California         CA 94114
# Country                USA              USA
# ...

# %%
df5 = df5_T.T

# %%
df5
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#   Employees      Continent
# 0         8  North America
# 1        15  North America
# 2        25  North America
# 3        10  North America
# 4        12  North America
# 5        20  North America

# %%
# Lesson - Adding Geocoding based on the address

# %%
from geopy.geocoders import Nominatim          # From geopy package, module geocoders, we are importing Nominatim class

# %%
nom = Nominatim()                              # Creating Object instance

# %%
np = nom.geocode("1 Sibley Park Road, Earley")   # Using geocode method the fetch the details

# %%
np
# Out:
# Location(1, Sibley Park Road, Earley, Shinfield, Wokingham, South East, England, RG6 5UB, UK, (51.42876135, -0.934302404509975, 0.0))

# %%
np.address
# Out:
# '1, Sibley Park Road, Earley, Shinfield, Wokingham, South East, England, RG6 5UB, UK'

# %%
np.latitude
# Out:
# 51.42876135

# %%
np.longitude
# Out:
# -0.934302404509975

# %%
df5
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#   Employees      Continent
# 0         8  North America
# 1        15  North America
# 2        25  North America
# 3        10  North America
# 4        12  North America
# 5        20  North America

# %%
df6 =df5

# %%
df6 = df5["GeoLoc"] = df5["Address"] + ", " + df5["City"] + ", " + df5["State"] + ", " + df5["Country"]

# %%
df6
# Out:
# 0           3666 21st St, San Francisco, CA 94114, USA
# 1         735 Dolores St, San Francisco, CA 94119, USA
# 2    332 Hill St, San Francisco, California 94114, USA
# 3           3995 23rd St, San Francisco, CA 94114, USA
# 4      1056 Sanchez St, San Francisco, California, USA
# 5        551 Alvarado St, San Francisco, CA 94114, USA
# dtype: object

# %%
df6
# Out:
# 0           3666 21st St, San Francisco, CA 94114, USA
# 1         735 Dolores St, San Francisco, CA 94119, USA
# 2    332 Hill St, San Francisco, California 94114, USA
# 3           3995 23rd St, San Francisco, CA 94114, USA
# 4      1056 Sanchez St, San Francisco, California, USA
# 5        551 Alvarado St, San Francisco, CA 94114, USA
# dtype: object

# %%
from geopy import Nominatim
from geopy.exc import GeocoderTimedOut

# %%
nom = Nominatim()

# %%
df5
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#   Employees      Continent                                             GeoLoc
# 0         8  North America         3666 21st St, San Francisco, CA 94114, USA
# 1        15  North America       735 Dolores St, San Francisco, CA 94119, USA
# 2        25  North America  332 Hill St, San Francisco, California 94114, USA
# 3        10  North America         3995 23rd St, San Francisco, CA 94114, USA
# ...

# %%
df6 = df5

# %%
df6
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#   Employees      Continent                                             GeoLoc
# 0         8  North America         3666 21st St, San Francisco, CA 94114, USA
# 1        15  North America       735 Dolores St, San Francisco, CA 94119, USA
# 2        25  North America  332 Hill St, San Francisco, California 94114, USA
# 3        10  North America         3995 23rd St, San Francisco, CA 94114, USA
# ...

# %%
df6["latitude"] = df6["GeoLoc"].apply(nom.geocode)
df6
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#   Employees      Continent                                             GeoLoc  \
# 0         8  North America         3666 21st St, San Francisco, CA 94114, USA
# 1        15  North America       735 Dolores St, San Francisco, CA 94119, USA
# 2        25  North America  332 Hill St, San Francisco, California 94114, USA
# 3        10  North America         3995 23rd St, San Francisco, CA 94114, USA
# ...

# %%
df6["longitude"] = df6["GeoLoc"].apply(nom.geocode)
df6
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#   Employees      Continent                                             GeoLoc  \
# 0         8  North America         3666 21st St, San Francisco, CA 94114, USA
# 1        15  North America       735 Dolores St, San Francisco, CA 94119, USA
# 2        25  North America  332 Hill St, San Francisco, California 94114, USA
# 3        10  North America         3995 23rd St, San Francisco, CA 94114, USA
# ...

# %%
df6["latitude"] = df6["latitude"].apply(lambda x: x.latitude if x!= None else None) # Changingthe Latitude
# Out:
# -----------------------------------------------------------------------
# AttributeError                        Traceback (most recent call last)
# <ipython-input-184-d92a4f409f66> in <module>()
# ----> 1 df6["latitude"] = df6["latitude"].apply(lambda x: x.latitude if x!= None else None)
#
# /Users/Kumaran/anaconda/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer (pandas/_libs/lib.c:66440)()
#
# <ipython-input-184-d92a4f409f66> in <lambda>(x)
# ----> 1 df6["latitude"] = df6["latitude"].apply(lambda x: x.latitude if x!= None else None)
#
# AttributeError: 'float' object has no attribute 'latitude'

# %%
df6
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#   Employees      Continent                                             GeoLoc  \
# 0         8  North America         3666 21st St, San Francisco, CA 94114, USA
# 1        15  North America       735 Dolores St, San Francisco, CA 94119, USA
# 2        25  North America  332 Hill St, San Francisco, California 94114, USA
# 3        10  North America         3995 23rd St, San Francisco, CA 94114, USA
# ...

# %%
df6["longitude"] = df6["longitude"].apply(lambda x: x.longitude if x!= None else None) #Changing the Longitude now

# %%
df6
# Out:
#   ID          Address           City             State Country         Name  \
# 0  1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1  2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2  3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3  4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#   Employees      Continent                                             GeoLoc  \
# 0         8  North America         3666 21st St, San Francisco, CA 94114, USA
# 1        15  North America       735 Dolores St, San Francisco, CA 94119, USA
# 2        25  North America  332 Hill St, San Francisco, California 94114, USA
# 3        10  North America         3995 23rd St, San Francisco, CA 94114, USA
# ...
